# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
from scipy.io import loadmat
from scipy.signal import stft
import pywt

plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号

# %% [markdown]
# #### 轴承四内圈破损

# %%
mat_data1 = loadmat('C:\\Users\HKFLYE\\Desktop\\轴承456加速退化寿命\\Bearing4_Life\\4-8.mat')

print(mat_data1.keys())

data1 = mat_data1['Datas']

column_data1 = data1[50000:150000, 1]/100  # 第一列数据

    # 创建时间序列，假设时间序列与数据点的数量相同
time_series1 = range(len(column_data1))

    # 绘制曲线
plt.plot(time_series1, column_data1)
plt.xlabel('')
plt.ylabel('')
plt.title(f'')
plt.xlim([0,100000])
plt.ylim([-8, 8])
plt.show()

#中度异常
mat_data2 = loadmat('C:\\Users\HKFLYE\\Desktop\\轴承456加速退化寿命\\Bearing4_Life\\4-18.mat')

print(mat_data2.keys())

data2 = mat_data2['Datas']

column_data2 = data2[50000:150000, 1]/90  # 第二列数据

    # 创建时间序列，假设时间序列与数据点的数量相同
time_series2 = range(len(column_data2))

    # 绘制曲线
plt.plot(time_series2, column_data2)
plt.xlabel('')
plt.ylabel('')
plt.title(f'')
plt.xlim([0,100000])
plt.ylim([-8, 8])
plt.show()

#重度异常
mat_data3 = loadmat('C:\\Users\HKFLYE\\Desktop\\轴承456加速退化寿命\\Bearing4_Life\\4-29.mat')

print(mat_data3.keys())

data3 = mat_data3['Datas']

column_data3 = data1[100000:200000, 1]/80  # 第一列数据

    # 创建时间序列，假设时间序列与数据点的数量相同
time_series3 = range(len(column_data3))

    # 绘制曲线
plt.plot(time_series3, column_data3)
plt.xlabel('')
plt.ylabel('')
plt.title(f'')
plt.xlim([0,100000])
plt.ylim([-10, 10])
plt.show()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'DataCount', 'LineCount', 'SampleFrequency', 'SampleStartTime', 'Datas'])
# dict_keys(['__header__', '__version__', '__globals__', 'DataCount', 'LineCount', 'SampleFrequency', 'SampleStartTime', 'Datas'])
# dict_keys(['__header__', '__version__', '__globals__', 'DataCount', 'LineCount', 'SampleFrequency', 'SampleStartTime', 'Datas'])

# %% [markdown]
# ### 轴承五外圈破损

# %%
mat_data1 = loadmat('C:\\Users\HKFLYE\\Desktop\\轴承456加速退化寿命\\Bearing5_Life\\5-3.mat')

print(mat_data1.keys())

data1 = mat_data1['Datas']

column_data1 = data1[50000:150000, 1]/100  # 第一列数据

    # 创建时间序列，假设时间序列与数据点的数量相同
time_series1 = range(len(column_data1))

    # 绘制曲线
plt.plot(time_series1, column_data1)
plt.xlabel('')
plt.ylabel('')
plt.title(f'')
plt.xlim([0,100000])
plt.ylim([-7, 7])
plt.show()

#中度异常
mat_data2 = loadmat('C:\\Users\HKFLYE\\Desktop\\轴承456加速退化寿命\\Bearing5_Life\\5-7.mat')

print(mat_data2.keys())

data2 = mat_data2['Datas']

column_data2 = data2[150000:250000, 1]/90  # 第二列数据

    # 创建时间序列，假设时间序列与数据点的数量相同
time_series2 = range(len(column_data2))

    # 绘制曲线
plt.plot(time_series2, column_data2)
plt.xlabel('')
plt.ylabel('')
plt.title(f'')
plt.xlim([0,100000])
plt.ylim([-8.5, 8.5])
plt.show()

#重度异常
mat_data3 = loadmat('C:\\Users\HKFLYE\\Desktop\\轴承456加速退化寿命\\Bearing5_Life\\5-11.mat')

print(mat_data3.keys())

data3 = mat_data3['Datas']

column_data3 = data1[150000:250000, 1]/80  # 第一列数据

    # 创建时间序列，假设时间序列与数据点的数量相同
time_series3 = range(len(column_data3))

    # 绘制曲线
plt.plot(time_series3, column_data3)
plt.xlabel('')
plt.ylabel('')
plt.title(f'')
plt.xlim([0,100000])
plt.ylim([-10, 10])
plt.show()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'DataCount', 'LineCount', 'SampleFrequency', 'SampleStartTime', 'Datas'])
# dict_keys(['__header__', '__version__', '__globals__', 'DataCount', 'LineCount', 'SampleFrequency', 'SampleStartTime', 'Datas'])
# dict_keys(['__header__', '__version__', '__globals__', 'DataCount', 'LineCount', 'SampleFrequency', 'SampleStartTime', 'Datas'])

# %% [markdown]
# ### 轴承六滚珠破损

# %%
mat_data1 = loadmat('C:\\Users\HKFLYE\\Desktop\\轴承456加速退化寿命\\Bearing6_Life\\6-9.mat')

print(mat_data1.keys())

data1 = mat_data1['Datas']

column_data1 = data1[0:100000, 1]/100  # 第一列数据

    # 创建时间序列，假设时间序列与数据点的数量相同
time_series1 = range(len(column_data1))

    # 绘制曲线
plt.plot(time_series1, column_data1)
plt.xlabel('')
plt.ylabel('')
plt.title(f'')
plt.xlim([0,100000])
plt.ylim([-7, 7])
plt.show()

#中度异常
mat_data2 = loadmat('C:\\Users\HKFLYE\\Desktop\\轴承456加速退化寿命\\Bearing6_Life\\6-20.mat')

print(mat_data2.keys())

data2 = mat_data2['Datas']

column_data2 = data2[0:100000, 1]/90  # 第二列数据

    # 创建时间序列，假设时间序列与数据点的数量相同
time_series2 = range(len(column_data2))

    # 绘制曲线
plt.plot(time_series2, column_data2)
plt.xlabel('')
plt.ylabel('')
plt.title(f'')
plt.xlim([0,100000])
plt.ylim([-9, 9])
plt.show()

#重度异常
mat_data3 = loadmat('C:\\Users\HKFLYE\\Desktop\\轴承456加速退化寿命\\Bearing6_Life\\6-33.mat')

print(mat_data3.keys())

data3 = mat_data3['Datas']

column_data3 = data1[150000:250000, 1]/80  # 第一列数据

    # 创建时间序列，假设时间序列与数据点的数量相同
time_series3 = range(len(column_data3))

    # 绘制曲线
plt.plot(time_series3, column_data3)
plt.xlabel('')
plt.ylabel('')
plt.title(f'')
plt.xlim([0,100000])
plt.ylim([-10, 10])
plt.show()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'DataCount', 'LineCount', 'SampleFrequency', 'SampleStartTime', 'Datas'])
# dict_keys(['__header__', '__version__', '__globals__', 'DataCount', 'LineCount', 'SampleFrequency', 'SampleStartTime', 'Datas'])
# dict_keys(['__header__', '__version__', '__globals__', 'DataCount', 'LineCount', 'SampleFrequency', 'SampleStartTime', 'Datas'])
